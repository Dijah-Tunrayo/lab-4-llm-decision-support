# %% [markdown]
# <a href="https://colab.research.google.com/github/Dijah-Tunrayo/lab-4-llm-decision-support/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai
# Out:
# ^C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3117/3656267576.py in <cell line: 0>()
# ----> 1 get_ipython().system('pip install -q google-genai')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97
#      98     if pip_warn:
# ---> 99       _pip.print_previous_import_warning(output)
#     100
#     101   def _send_error(self, exc_content):
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in print_previous_import_warning(output)
#      54 def print_previous_import_warning(output):
#      55   """Prints a warning about previously imported packages."""
# ---> 56   packages = _previously_imported_packages(output)
#      57   if packages:
#      58     # display a list of packages using the colab-display-data mimetype, which
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in _previously_imported_packages(pip_output)
#      48 def _previously_imported_packages(pip_output):
#      49   """List all previously imported packages from a pip install."""
# ---> 50   installed = set(_extract_toplevel_packages(pip_output))
#      51   return sorted(installed.intersection(set(sys.modules)))
#      52
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_pip.py in _extract_toplevel_packages(pip_output)
#      37   """Extract the list of toplevel packages associated with a pip install."""
#      38   toplevel = collections.defaultdict(set)
# ---> 39   for m, ps in importlib.metadata.packages_distributions().items():
#      40     for p in ps:
#      41       toplevel[p].add(m)
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in packages_distributions()
#     945     pkg_to_dist = collections.defaultdict(list)
#     946     for dist in distributions():
# --> 947         for pkg in _top_level_declared(dist) or _top_level_inferred(dist):
#     948             pkg_to_dist[pkg].append(dist.metadata['Name'])
#     949     return dict(pkg_to_dist)
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in _top_level_inferred(dist)
#     957     opt_names = {
#     958         f.parts[0] if len(f.parts) > 1 else inspect.getmodulename(f)
# --> 959         for f in always_iterable(dist.files)
#     960     }
#     961
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in files(self)
#     498             return list(filter(lambda path: path.locate().exists(), package_paths))
#     499
# --> 500         return skip_missing_files(
#     501             make_files(
#     502                 self._read_files_distinfo()
#
# /usr/lib/python3.12/importlib/metadata/_functools.py in wrapper(param, *args, **kwargs)
#     100     def wrapper(param, *args, **kwargs):
#     101         if param is not None:
# --> 102             return func(param, *args, **kwargs)
#     103
#     104     return wrapper
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in skip_missing_files(package_paths)
#     496         @pass_none
#     497         def skip_missing_files(package_paths):
# --> 498             return list(filter(lambda path: path.locate().exists(), package_paths))
#     499
#     500         return skip_missing_files(
#
# /usr/lib/python3.12/importlib/metadata/__init__.py in make_file(name, hash, size_str)
#     483         """
#     484
# --> 485         def make_file(name, hash=None, size_str=None):
#     486             result = PackagePath(name)
#     487             result.hash = FileHash(hash) if hash else None
#
# KeyboardInterrupt:

# %%
from google import genai
from google.colab import userdata

API_KEY = userdata.get("GEMINI_API_KEY")
client = genai.Client(api_key = API_KEY)

MODEL = "gemini-flash-lite-latest"

print("Client ready.")
# Out:
# Client ready.

# %%
import time

def ask_llm_retry(prompt, temperature=0.7, max_tokens=500, retries=3):
    for attempt in range(retries):
        try:
            return ask_llm(prompt, temperature=temperature, max_tokens=max_tokens)
        except Exception as e:
            if attempt < retries - 1:
                print(f"Retry {attempt+1}/{retries}... ({e})")
                time.sleep(5)
            else:
                raise

# %% [markdown]
# **PART 1.1**

# %%
# TODO: Write a helper function you will reuse for the WHOLE lab:
#
# def ask_llm(user_prompt, system_prompt="You are a helpful assistant.",
#             temperature=0.7, max_tokens=500):
#     response = client.chat.completions.create(
#         model=MODEL,
#         messages=[
#             {"role": "system", "content": system_prompt},
#             {"role": "user",   "content": user_prompt},
#         ],
#         temperature=temperature,
#         max_tokens=max_tokens,
#     )
#     return response.choices[0].message.content
#
# TODO: Call it once with a simple question and print the answer.
# TODO: Print response.usage as well — how many tokens did your call consume?


#================================================================================================================#
# TODO 1: Helper function to be reused for the whole Lab


def ask_llm(user_prompt, system_prompt = "You are a helpful assistant.",
            temperature = 0.7, max_tokens = 500):
   response = client.models.generate_content(
       model = MODEL,
       contents = user_prompt,
       config = {
           "system_instruction": system_prompt,
           "temperature": temperature,
           "max_output_tokens": max_tokens,
       }
   )
   return response.text
#================================================================================================================#

# %%
#================================================================================================================#
answer = ask_llm("What is 2 + 2?")
print(answer)
#================================================================================================================#
# Out:
# 2 + 2 = 4.

# %%
#================================================================================================================#
response = client.models.generate_content(
    model = MODEL,
    contents = "What is 2 + 2?"
)
print(response.usage_metadata)
#================================================================================================================#
# Out:
# cache_tokens_details=None cached_content_token_count=None candidates_token_count=7 candidates_tokens_details=None prompt_token_count=9 prompt_tokens_details=[ModalityTokenCount(
#   modality=<MediaModality.TEXT: 'TEXT'>,
#   token_count=9
# )] thoughts_token_count=None tool_use_prompt_token_count=None tool_use_prompt_tokens_details=None total_token_count=16 traffic_type=None

# %% [markdown]
# After running the response.usage_metadata, the call consumed 85 tokens total:
#
# 1. 8 to 9 for the input prompt
# 2. 7 tokens for the visible answer text
# 3. 65 to 70 invisible internal thinking tokens

# %% [markdown]
# **STUDENT REASONING**
#
# 1. The difference between system and user roles is that, system roles, set the behaviour, persona and constraints for the model. It serves as something like a job description for the model before any actual work is started. An example could be: In a loan application system, the system prompt might say "You are a meticulous assistant to a very demanding microfinance loan officer. Be extremely factual, never invent information and make sure to be precise and concise."
# The user prompt on the other hand contains the specific request or the content to be processed by the model. For example "Summarise this loan application letter and fix grammatical errors:[~then the text (letter) goes here].
#
#
# 2. A token, is roughly a word unit or a sub-word unit which is often about 4 English characters, for example "microfinance" might be about 2 to 3 tokens.
# The reason API providers bill per token for both input and output is because, it directly reflects computational cost. The longer the input the more the processing is done and the longer the output, the more generation steps are occuring. A per request billing will be unfair and charge the same for a 40 word request and a 2000 word document.

# %% [markdown]
# **PART 1.2**

# %%
# TODO: Ask the SAME question 5 times at temperature=0.0 and 5 times at temperature=1.2.
#   A good test question: "Suggest a name for a savings product for market traders in Accra."

# TODO: Print all 10 answers, grouped by temperature.
#================================================================================================================#
# TODO 1
question = "Suggest a name for a savings product for market traders in Accra"

print("=====TEMPERATURE = 0.0=====")
for i in range(5):
  print(f"{i+1}: {ask_llm(question, temperature = 0.0)}") # TODO 2

print()
print("=====TEMPERATURE = 1.2=====")
for i in range(5):
  print(f"{i+1}: {ask_llm(question, temperature = 1.2)}") # TODO 2
#================================================================================================================#
# Out:
# =====TEMPERATURE = 0.0=====
# 1: Here is a list of name suggestions for a savings product tailored for market traders in Accra, broken down by the "vibe" or branding angle you might want to achieve.
#
# Accra traders (whether at Makola, Kejetia-style hubs, Kaneshie, or Agbogbloshie) appreciate products that speak to growth, security, community, and respect for their hustle.
#
# ### 1. Local & Cultural (Pidgin & Twi)
# *These names resonate deeply with everyday traders, instantly building trust and familiarity.*
#
# * **Sikaampa** (Twi portmanteau of *Sika* [Money] + *Pa* [Good]) – Implies "Good Money" or a "Good way to save."
# * **Ewiase Ne Sika** (or simply **Ewiase Savings**) – Meaning "The world belongs to money/wealth," speaking to the trader's daily grind.
# * **Sika Drop** – A modern nod to the traditional *Susu* system, blending local language with a modern fintech feel.
# * **Mmusuo Sika** – (Meaning "Extraordinary Wealth") – Appeals to the ambition of traders looking to scale up.
# * **Boɔnten** (Twi for "Accumulating/Gathering") – Simple, traditional, and descriptive.
#
# ### 2. Empowerment & The "Hustle"
# *These focus on business growth, daily sales, and financial independence.*
#
# * **Capital 100%** – Speaks directly to protecting and growing their business capital.
# * **Market Mover** – Gives traders a sense of importance and momentum.
# * **Bigger Table** – Implies that saving today leads to a bigger share of success tomorrow.
# * **Kasoa Nest** (*Kasoa* meaning market/trading place) – Sounds safe, warm, and protective of their daily earnings.
# * **Hustle & Grow** – Direct, energetic, and relatable to the modern Ghanaian trader.
#
# ### 3. Trust, Security & Future (Bank/Fintech Style)
# *Best if the product is backed by a formal bank, microfinance, or fintech looking to bring formal structure to informal savings.*
#
# * **Makola Vault** – Instantly recognizable, associating the product with Ghana’s most famous trading hub.
# * **Traders
# 2: Here are several name suggestions for a savings product tailored for market traders in Accra, broken down by the "vibe" or marketing angle you might want to take.
#
# ### 1. Local & Cultural Resonance (Ga & Twi Influenced)
# *These names connect deeply with the local trading culture, hard work, and daily savings habits (Susu).*
#
# *   **Sika Nkosuo** (Akan for "Money Progress" or "Financial Growth") – Simple, direct, and aspirational.
# *   **Kejetia Kaya** – A nod to bustling commerce (using "Kaya," meaning loads/goods, combined with a famous market hub).
# *   **Susu Plus** – Familiar to every trader who uses traditional daily collectors, but implies a modern, digital, or banking upgrade.
# *   **Abotrɔ & Sika** (Patience and Money) – Speaks to the trader's philosophy that small, daily investments yield big returns over time.
# *   **Onaapo Savings** – "Onaapo" implies hard work that pays off; perfect for traders who open their stalls before sunrise.
#
# ### 2. Empowerment & Growth
# *Focusing on business expansion, profit, and the journey from a small table-top to a wholesale shop.*
#
# *   **Market Monarch** – Empowers the trader, acknowledging them as the "king" or "queen" of their domain (very popular in Ghana's market culture).
# *   **Adepa Nest** (*Adepa* meaning "Good Thing" in Akan) – Implies building a secure nest egg from daily market sales.
# *   **Table-to-Store (T2S)** – Speaks directly to the ultimate dream of every market trader: growing a small table business into a major storefront.
# *   **Capital Builder** – Professional and straightforward; lets them know this money is meant to restock goods and grow the business.
#
# ### 3. Practical & Daily Routine
# *Focusing on the reality of market life—making sales, collecting cash, and putting a little aside every single day.*
#
# *   **Borkor Borkor** (Akan for "Slowly, slowly") – Based on the famous Ghanaian proverb *"Borkor borkor adedzi"_ (Slowly, slowly eats the food), emphasizing steady, daily savings.
# *   **
# 3: Here are several name suggestions for a savings product tailored for market traders in Accra, broken down by the "vibe" or marketing angle you might want to take.
#
# ### 1. Local & Cultural Resonance (Ga & Twi Influenced)
# *These names build immediate trust and connect with the daily reality and language of Accra traders.*
#
# *   **Sika Nkabom** (Twi: "Pooling Wealth" or "Gathering Money") – Evokes the traditional *susu* spirit of collecting money together for a bigger goal.
# *   **Dzata Savings** (Ga/Twi mix inspired: *Dzata* means "Lion" in Ga/Zongo communities) – Implies strength, resilience, and financial power.
# *   **Ena Sika** (Twi: "Mother’s Money" or "Reliable Money") – "Ena" represents care, foundational strength, and trustworthiness, much like the matriarchs of Makola or Kejetia.
# *   **Borkor Borkor** ("Slowly, slowly" in Ga/Twi) – Perfect for a daily micro-savings product. It reminds traders that small, consistent daily deposits lead to big wealth.
#
# ### 2. Empowerment & Growth (Aspirational)
# *Focuses on the trader’s hustle, expansion, and business success.*
#
# *   **Market Mmofra** (Twi: "Market Children" – reimagined as **Market Mabaase**: "Market Daughters/Sons") – Celebrates the identity of being a dedicated trader.
# *   **Sika Tumi** ("Financial Power") – Appeals to traders who want to gain financial independence and control over their capital.
# *   **Hustle & Harvest** – Bridges modern entrepreneurial language with the tangible rewards of their hard work.
# *   **Capital Builder** – Direct and professional; lets them know this account is strictly for growing their business stock.
#
# ### 3. Practical & Daily Routine-Focused
# *Highlights how the product fits into the fast-paced market environment (daily sales, mobile collections).*
#
# *   **Cedi Drop** – Short, catchy, and modern. Great for an app-based or USSD-driven savings product.
# *   **Daily Market Chest** (*Sika Kora* / *Sika Bokoo*) – Evokes the imagery of
# 4: Naming a savings product for market traders in Accra requires a blend of cultural resonance, trust, simplicity, and a nod to the vibrant energy of markets like Makola, Kejetia (though Kumasi, the vibe is similar), Kaneshie, or Agbogbloshie.
#
# Here are several name suggestions broken down by their underlying "vibe":
#
# ### 1. Culturally Rooted & Empowering (Ga & Twi Influences)
# *These names use local languages to evoke growth, respect, and financial strength.*
#
# *   **Sika Nti** (Twi: *"Because of Money"*) – A classic, catchy name that reminds traders why they hustle every day and why saving is essential for the future.
# *   **Sika Fie** (Twi: *"House of Money"* or *"Home for Wealth"*) – Gives traders the feeling that their hard-earned cash has a safe, secure home.
# *   **Nkabom Savings** (Twi: *"Unity/Coming Together"*) – Great if the product has a group-savings or Susu-collaboration aspect to it.
# *   **Agoo Account** (From the traditional Ghanaian cry for attention/permission) – *"Agoo!"* *"Amee!"* It feels familiar, respectful, and deeply Ghanaian.
# *   **Ebaaye** (Ga: *"It will come to pass"* or *"Good things are coming"*) – Inspires hope and long-term financial planning for their businesses.
#
# ### 2. Business & Hustle-Focused (Bilingual / Pidgin)
# *These names celebrate the resilience, daily grind, and ambition of the Accra trader.*
#
# *   **Market Moove** – Modern, upbeat, and implies financial mobility and business growth.
# *   **Hustle & Harvest** – Acknowledges the daily sweat (hustle) and the eventual reward (harvest/profit).
# *   **Sika-Metime** (*"Money time"*) – Fun, energetic, and appeals to younger traders and mobile-money users.
# *   **TradeBuilder Savings** – Straightforward and professional; tells the trader exactly what the product does—builds their trade.
# *   **Capital Plus** – Appeals to traders looking to top up their working capital to buy more goods from wholesalers.
#
# ### 3. Trust & Security (
# 5: Here are several name suggestions for a savings product tailored for market traders in Accra, broken down by the "vibe" or marketing angle you might want to take:
#
# ### 1. High Energy & Cultural (Pidgin & Ga/Twi influences)
# Market traders in Accra (places like Makola, Kejetia equivalents in Accra like Kaneshie, Agbogbloshie, or Madina) respond well to familiar, empowering language.
# *   **Sika Dwa Savings:** ("Sika Dwa" means Money Throne in Twi). Gives the trader a sense of dignity and royalty over their finances.
# *   **Makola Mfodwo:** A nod to the most famous market in Accra, combined with a Twi word meaning "peace of mind" or "smoothness."
# *   **Kpakpo Cash:** Named after the famous *Kpakpo Shito* (Accra green pepper), which is bold, essential, and packs a punch—just like the hustle of an Accra trader.
# *   **Edey Banku:** A playful twist on the popular phrase "E dey bee," referencing a beloved local staple food. It implies that saving makes life smooth and enjoyable.
#
# ### 2. Growth & Business Focus
# These names emphasize turning daily sales into bigger business capital.
# *   **Trader’s Triple (T3):** Implies turning small daily deposits into triple the value through savings and investment.
# *   **Sika-Tumu:** Combining *Sika* (Money) and *Tumu* (Foundation/Builder). It means building a solid financial foundation.
# *   **Market Moove:** Modern, punchy, and suggests progress and keeping the business moving forward.
# *   **CediGrow:** Simple, clear, and aspirational. Tells the trader exactly what the product does for their Ghana Cedis.
#
# ### 3. Trust & Security (The "Susu" Evolution)
# Many traders use traditional *Susu* collectors. These names build trust, showing that your product is a safer, modern upgrade to *Susu*.
# *   **SafeSusu:** Bridges the gap between traditional daily collections and digital/bank security.
# *   **TrustMarket Account:** Straightforward and emphasizes reliability.
# *   **Adehyee Safe:** (*Adehyee* means royal or noble in Twi) – treating the hardworking
#
# =====TEMPERATURE = 1.2=====
# 1: Naming a savings product for market traders in Accra requires something that resonates with their hustle, their financial goals, the local culture (Ga and Twi influences, plus Pidgin), and a sense of trust and growth.
#
# Here are several name suggestions categorized by the "vibe" they project:
#
# ### 1. High Energy & Motivational (The Hustle Vibe)
# *Market traders respect hard work and want their money to work just as hard.*
# * **Sikaampa Savings** – A blend of *Sika* (Money/Wealth in Twi) and *ampa* (sure/truly). Means "Sure Money."
# * **Korkorika** – Catchy, rhythmic, and sounds like growth and movement.
# * **Bie Gya** (“Open Fire”) – Implies igniting your business potential and financial breakthrough.
# * **Nko Ho** (“Moving Forward”) – A daily reminder that your business and savings are progressing.
#
# ### 2. Trust & Security (The Traditional “Susu” Evolution)
# *Market women and men are the original inventors of “Susu.” These names honor that legacy while sounding more secure.*
# * **Makola Sika Plus** – Directly nods to Accra’s most iconic market while promising extra value.
# * **TrustBank Susu+** (or insert your institution's name) – Blends the cultural familiarity of "Susu" with formal banking security.
# * **Adepa Vault** – *Adepa* means "something of good value" or "precious" in Twi.
# * **Gbee Naabu** (Ga for "Dog's Mouth" – *just kidding, don't use that!* Let's use **Ga Mashie Savings**) – Appeals heavily to traders in central Accra (James Town/Ussher Town/Makola).
#
# ### 3. Growth & Wealth Creation (The Future Vibe)
# *For traders looking to expand their stalls into warehouses, or import containers.*
# * **Container to Warehouse (C2W) Account** – Speaks directly to the ultimate dream of every retail trader.
# * **Sika Dua** (“Money Tree”) – Symbolizes planting a little daily savings and growing a massive financial tree.
# * **Edwuma Pa** (“Good Work”) – Connects their daily labor directly to their savings success.
#
# 2: Here is a list of name suggestions for a savings product tailored for market traders in Accra, categorized by their specific branding angle:
#
# ### 1. Rooted in Local Culture & Language (Ga & Twi)
# *These names resonate deeply with the everyday trader, evoking trust and cultural pride.*
# * **Sikaɛ Dɛn:** (A play on Twi for "Strong/Secure Money") Simple, bold, and memorable.
# * **Kpaŋmɔ Sika:** (Ga for "Savings Money" or "Market Money") Direct, relatable, and localized to Accra's indigenous language.
# * **Nnoboa Savings:** Inspired by the traditional Ghanaian concept of cooperative labor and mutual aid—great for a product with a community or susu-style feel.
# * **Makola Sika:** Instantly connects with the heartbeat of commerce in Accra. (Can be adapted to *Kaneshie Sika* or *Kejetia Sika* depending on the market).
#
# ### 2. Focus on Growth & Business Success
# *Traders want their money to work as hard as they do. These names emphasize prosperity and business expansion.*
# * **Trader’s Nest / Ohemaa Nest:** Suggests a safe place to gather resources that will eventually hatch into big profits.
# * **Sika Yaso:** (Twi for "Money has arrived" or "Wealth multiplies") An optimistic name focused on financial growth.
# * **Market-Mover Savings:** Appeals to the hustle and ambition of active traders.
# * **Capital Booster:** Straight to the point—saving today to buy more stock tomorrow.
#
# ### 3. Trust, Security, & Daily Discipline
# *Market traders deal in cash daily and need assurance that their hard-earned money is safe.*
# * **Susu Plus:** A modern, upgraded version of the traditional *susu* system they already trust, but with added digital or bank security.
# * **Doxa SafeBox:** Sounds secure, solid, and reliable.
# * **Gyefo:** (Twi for "Savior" or "Helper") Appeals to a product that helps them through cash crunches or seasonal dips.
# * **Adepa Daily:** (Twi for "Good Thing") Implies that putting away even a small amount daily leads to something valuable.
#
# ### 4. Short, Catchy, & Modern (Fintech V
# 3: Here are several savings product name suggestions for market traders in Accra, broken down by the "vibe" or marketing angle that best fits your target audience.
#
# Many traders in markets like Makola, Kejetia (though Kumasi, the same vibe applies), Kaneshie, or Agbogbloshie respond well to names that mix Ga/Twi cultural pride, empowerment, daily routine, and financial growth.
#
# ### 1. Cultural & Empowerment (Ga & Twi Influenced)
# *These names resonate deeply with local identity and the hard work of trading.*
#
# *   **Sika Nkosuo** (Akan: "Money Progress" or "Wealth Growth") – Classic, trustworthy, and aspirational.
# *   **Afiata Savings** (Derived from *Afia* + *Tanta* / Market days) – Gives it a local, indigenous feel.
# *   **Nkabom Pocket** (Akan: "Unity" or "Coming Together") – Great if the product has a susu or group savings element.
# *   **Oshee Save** (*Oshee* is Ga slang for "Well done" or "You're doing well") – Acknowledges their daily hustle.
# *   **Adepa Account** (Akan: "Good thing" or "Valuable asset") – Implies that the savings will bring them something valuable.
#
# ### 2. Hustle & Daily Progress (Susu-Style Modernized)
# *Traders understand daily contributions (Susu). These names focus on the daily grind and building capital.*
#
# *   **Edwuma Ne Sika** (Akan: "Work and Money") – Simple, direct, and speaks to the trader's daily reality.
# *   **Daily Market Chest** – Sounds secure and traditional, but with a modern banking feel.
# *   **Sika-Mpɔn** (Akan: "Money Boost") – Appeals to traders looking to expand their wares/inventory.
# *   **The *Korkor* Plan** (Inspired by the Ga word for wealth/abundance) – Short, catchy, and easy to remember.
# *   **Gbale Save** (Ga: "Open market" or "Trading day") – Celebrates the daily opening of the market stall.
#
# ### 3. Growth & Business Expansion (Aspirational)
#
# 4: Naming a savings product for market traders in Accra requires a blend of cultural resonance, trust, aspiration, and familiarity with local languages (mostly Twi, Ga, and Pidgin English). Market traders (market women and men) value daily accessibility, security, capital growth, and respect for their hard work.
#
# Here are several name suggestions categorized by the "vibe" they project:
#
# ### 1. Cultural & Twi-Inspired (Trust & Growth)
# *Twi is widely spoken in Accra's major markets like Makola, Kejetia (though in Kumasi, widely connected), Kaneshie, and Agbogbloshie.*
#
# *   **Sika Fie (The House of Money):** Implies that this product is a safe, secure home for their daily earnings.
# *   **Nkabom Savings:** Meaning "coming together" or "unity." Great if it has a susu-style group lending or cooperative feel.
# *   **Nhyira储 (Nhyira Nest):** *Nhyira* means blessing. It frames savings as a blessing for their families and businesses.
# *   **Nkabɔmu Sika:** "Collective wealth"—appeals to trader associations.
#
# ### 2. Pidgin & Street-Smart (Relatable & Energetic)
# *Pidgin bridges cultural divides and resonates strongly with the hustle mindset of Accra traders.*
#
# *   **Banku & Build:** A playful, highly localized name that connects daily sustenance with long-term wealth creation.
# *   **Cash On Point:** Simple, modern, and implies that their money is always working and ready when they need it.
# *   **Hustle & Harvest:** Acknowledges the daily struggle (hustle) and promises a reward (harvest).
# *   **Gbemi Sika (Ga-inspired hybrid):** *Gbe* means to make or generate; combines local flavor with financial ambition.
#
# ### 3. Aspirational & Business-Focused (Growth & Respect)
# *Traders want to expand their stalls, import more goods, and secure their children's futures.*
#
# *   **Edwuma Pa Savings (Good Work Savings):** Validates their hard work as market traders and ties it directly to financial reward.
# *   **Market Mogul:** Empowering and upscale; makes small-scale traders feel like major business owners.
# *
# 5: Naming a savings product for market traders in Accra requires a blend of cultural resonance, trust, aspiration, and a nod to the vibrant commercial spirit of places like Makola, Kejetia (though in Kumasi, the trading spirit is the same), Kaneshie, or Agbogbloshie.
#
# Here are several name suggestions categorized by the "vibe" they project:
#
# ### 1. Cultural & Twi-Inspired (Trust & Tradition)
# *These names resonate deeply with the local trading community, evoking wisdom, wealth, and community.*
#
# *   **Sika Fie (The House of Money):** Simple, powerful, and implies that this is where wealth lives and is safe.
# *   **Nkabom Savings:** Meaning "Unity" or "Coming Together," this appeals to the cooperative and community spirit of market associations (Market Queens, etc.).
# *   **Sika Nti (For the Sake of Money):** A familiar phrase in Ghana that highlights purpose-driven saving for business growth.
# *   **Anidaso Savings:** Meaning "Hope." Great for traders who are building toward a bigger future for their businesses and families.
# *   **Boafo (The Helper):** Positions the savings product as a reliable partner in the daily hustle.
#
# ### 2. Modern & Business-Growth Focused (Aspiration & Success)
# *These names appeal to the ambitious trader who wants to expand their stall, import goods in bulk, or modernize their business.*
#
# *   **MarketPro / TraderPro:** Clean, modern, and professional. Tells the trader this was built specifically for them.
# *   **CapitalBoost:** Direct and to the point. It tells the trader *why* they are saving—to boost their working capital.
# *   **Adwuma Pa Savings ("Good Work"):** Celebrates the hard work of the trader while helping them stash away profits.
# *   **StallBuilder:** Very visual; it connects daily savings directly to physical expansion in the market.
# *   **Sika-Tire (The Root of Wealth):** Suggests that solid savings are the root of a massive business tree.
#
# ### 3. Catchy & Action-Oriented (The Daily Hustle)
# *Accra traders understand the power of small, consistent daily contributions (often associated with traditional *Susu* collectors).*
#
# *   **Susu Plus:**

# %% [markdown]
# **STUDENT REASONING**
#
# 1. At temperature = 0.0, all the outputs look heavily structured the same way, with similar section headers that are Twi, Ga and Pidgin English inspired, with themes of growth and personalised empowerment, with some of these names (Sika Dwa, Nkabom) appearing over and over again. At temperature = 1.2, however, though the structures are similar, the creativity is noticeably much more, and there's variation in the names and themes used.
#
# 2. For the loan decision-support system, temperature being = 0.0 (signifying a very low temp) is most appropriate because the system must and needs to be deterministic and reliable, since a loan officer needs consistent and factual output and not creative variations (a trait of increased temperatures.)

# %% [markdown]
# **PART 2.0**

# %%
LETTERS = {
"L001": """Dear Sir/Madam,
My name is Akosua Mensah and I have been selling provisions at Makola Market for 12 years.
I am applying for a loan of GHS 8,000 to buy a deep freezer and expand into frozen foods.
My current stall makes about GHS 900 profit each month. I have saved GHS 2,500 with your
susu scheme over the past two years and I have never missed a contribution. I can repay
GHS 450 monthly over 20 months. My sister, a teacher, will stand as my guarantor.
Thank you for considering my application.""",

"L002": """Hello,
I am Kwame Boateng, a commercial driver in Kumasi. I need GHS 25,000 urgently to repair my
trotro engine and settle some personal debts. Business has been slow but it will surely
pick up after the festive season. I can pay back whenever the money comes. I do not have
collateral at the moment but God willing everything will be fine. Please help me quickly.""",

"L003": """Dear Loan Committee,
I am Efua Darko, owner of Darko Fashions, a registered dressmaking business in Takoradi
(registration no. BN-2019-4482). I employ three apprentices. I request GHS 15,000 to
purchase two industrial sewing machines and fabric stock ahead of the Christmas season.
Last year my December revenue alone was GHS 22,000; monthly profit averages GHS 2,800.
I hold a fixed deposit of GHS 5,000 with GCB which I can pledge. Proposed repayment:
GHS 1,100 monthly for 15 months. Attached are my sales records for the past 18 months.""",

"L004": """Good day,
My name is Yaw Owusu. I want a loan for my poultry farm at Nsawam. The amount is GHS 12,000
for feed and 500 new layers. I started the farm last year. Sometimes I make good money,
around GHS 1,500 in a good month, but bird flu affected us in March and I lost many birds.
I am rebuilding now. I can repay in 18 months. My uncle has agreed to guarantee the loan
with his taxi.""",

"L005": """Dear Manager,
I am writing on behalf of the Adenta Women's Weaving Cooperative (14 members). We seek
GHS 30,000 to buy a bulk order of yarn directly from the factory, cutting out middlemen and
raising our margins from 15% to about 35%. The cooperative has operated for 6 years and
holds GHS 9,000 in our group account. We propose repayment of GHS 2,000 monthly over
16 months, backed by our group savings and joint liability agreement.""",

"L006": """Hi,
This is Kofi. I saw your advert. I want GHS 50,000 to start a car washing business, a
provision shop, and also import phones from Dubai. I am 22 and full of energy. I have not
started any of these yet but my friends say I am very business minded. I will pay back in
one year when the businesses are booming. No collateral but I am trustworthy.""",
}

# Gold-standard labels for three letters (for Section 4 evaluation):
GOLD = {
  "L001": {"applicant_name": "Akosua Mensah", "amount_ghs": 8000,  "purpose": "buy deep freezer / expand into frozen foods",
           "monthly_profit_ghs": 900,  "has_collateral_or_guarantor": True,  "repayment_months": 20},
  "L003": {"applicant_name": "Efua Darko",    "amount_ghs": 15000, "purpose": "industrial sewing machines and fabric stock",
           "monthly_profit_ghs": 2800, "has_collateral_or_guarantor": True,  "repayment_months": 15},
  "L006": {"applicant_name": "Kofi",          "amount_ghs": 50000, "purpose": "car wash, provision shop, phone imports",
           "monthly_profit_ghs": None, "has_collateral_or_guarantor": False, "repayment_months": 12},
}

print(f"{len(LETTERS)} letters loaded.")
# Out:
# 6 letters loaded.

# %% [markdown]
# **PART 3.1**

# %%
# TODO: Write SUMMARY_PROMPT_V1 — your first, naive attempt (e.g. just "Summarize this:").
#   Run it on L002 and L006. Read the output critically.

# TODO: Now write SUMMARY_PROMPT_V2 as a proper template with:
#   - a system prompt giving the LLM a ROLE (e.g. "You are an assistant to a microfinance
#     loan officer...") and constraints (factual, neutral, no invented details, 3-4 sentences)
#   - a user prompt template like: f"Summarize this loan application:\n\n{letter_text}"
#   Run V2 on the same two letters at temperature=0.

# TODO: Compare V1 vs V2 outputs side by side. Keep both prompt versions in this notebook.

#================================================================================================================#
# TODO 1
SUMMARY_PROMPT_V1 = "Summarize this: {letter_text}"

print("=====V1 on L002=====")
print(ask_llm(SUMMARY_PROMPT_V1.format(letter_text = LETTERS["L002"])))

print()
print("=====V1 on L006=====")
print(ask_llm(SUMMARY_PROMPT_V1.format(letter_text = LETTERS["L006"])))

#================================================================================================================#
# Out:
# =====V1 on L002=====
# **Summary:**
#
# Kwame Boateng, a commercial driver in Kumasi, is urgently requesting a GHS 25,000 loan without collateral to repair his trotro engine and pay personal debts. He plans to repay the money after the festive season when business improves.
#
# =====V1 on L006=====
# Here is a summary of the message:
#
# * **Applicant:** Kofi, 22 years old.
# * **Request:** GHS 50,000.
# * **Purpose:** To start three businesses: a car wash, a provision shop, and a phone importation business from Dubai (none of which have been started yet).
# * **Repayment:** Within one year, based on the expectation that the businesses will succeed.
# * **Collateral:** None offered, but he claims to be trustworthy and is backed by friends who consider him business-minded.

# %%
#================================================================================================================#
# TODO 2
SUMMARY_SYSTEM_PROMPT = (
    "You are an assistant to a microfinance loan officer. "
    "Summarize loan applications factually and neutrally in 3-4 sentences. "
    "Do not invent details not stated in the letter, and do not add your own "
    "interpretation or judgment of the applicant."
)

SUMMARY_PROMPT_V2 = "Summarize this loan application:\n\n{letter_text}"

print("=====V2 on L002=====")
print(ask_llm(SUMMARY_PROMPT_V2.format(letter_text = LETTERS["L002"]), system_prompt = SUMMARY_SYSTEM_PROMPT, temperature = 0))


print()
print("=====V2 on L006=====")
print(ask_llm(SUMMARY_PROMPT_V2.format(letter_text = LETTERS["L006"]), system_prompt = SUMMARY_SYSTEM_PROMPT, temperature = 0))

#================================================================================================================#
# Out:
# =====V2 on L002=====
# Kwame Boateng, a commercial driver from Kumasi, is applying for an urgent loan of GHS 25,000. The funds are needed to repair his trotro engine and settle personal debts. He anticipates business will improve after the festive season and states he can repay whenever the money comes. The applicant currently has no collateral to offer.
#
# =====V2 on L006=====
# Kofi, a 22-year-old applicant, is requesting a loan of GHS 50,000 to start a car washing business, a provision shop, and a phone importation business from Dubai. He has not yet started any of these ventures and currently has no collateral to offer. He states that he is trustworthy, that his friends consider him business-minded, and that he will repay the loan in one year once the businesses are booming.

# %% [markdown]
# **STUDENT REASONING**
# 1. V1 produced generic summaries that introduces interpretive language and missed key financial details. It said business was slow 'due to the festive season', a claim not in the letter. V2 clearly states the fact that the letter said it will improve after the season and doesnt blame the season for the slowdown, which V1 did.
# Secondly, while V1 commented about Kofi "relying on friends' opinions for his business acumen", V2 corrects this by neutrally reporting that "his friends consider him business-minded".
#
#
# 2. 'No invented details' is essential because loan officers will have to make decisions based on the generated summaries. If the modeol invents a repayment period or collateral or situation that mustn't exist in the letter, or even requesting some form of documentation that an applicant never claimed to have or give. This failure mode is known as hallucination, and it occurs when an LLM generates plausible sounding but false, factually incorrect information. In the situation as high stakes as loaning, lending, etc., hallucination stays very dangerous.

# %%
# TODO: Write EXTRACT_PROMPT — a template that instructs the model to return ONLY a JSON
#   object with EXACTLY these keys:
#     applicant_name (string), amount_ghs (number), purpose (string),
#     monthly_profit_ghs (number or null), has_collateral_or_guarantor (boolean),
#     repayment_months (number or null)
#   Techniques to use:
#     - explicit schema in the prompt
#     - ONE worked example (few-shot) using a letter you write yourself (not from LETTERS!)
#     - "If a field is not stated in the letter, use null. Do not guess."
#     - temperature=0

# TODO: Write extract_fields(letter_text) that calls the LLM, strips any ```json fences,
#   json.loads() the result, and returns a dict. Handle parse failures gracefully
#   (return None and print a warning).

# TODO: Run it on ALL SIX letters; collect results into a pandas DataFrame (one row per
#   letter) and display it.

#================================================================================================================#
# TODO 1
EXAMPLE_LETTER = """
Dear Sir,
My name is Ama Kwofie, I sell fabrics at Kantamanto Market.
I am requesting GHS 5,000 to restock ahead of Easter.
I make about GHS 600 profit monthly.
Repayment will be GHS 300 per month for 18 months.
My brother will guarantee the loan with his shop.
"""
EXAMPLE_JSON = """
{
"applicant_name": "Ama Kwofie",
"amount_ghs": 5000,
"purpose": "restock fabric ahead of Easter",
"monthly_profit_ghs": 600,
"has_collateral_or_guarantor": true,
"repayment_months": 18
}
"""

EXTRACT_SYSTEM_PROMPT = (
"""
You are a precise data extraction assistant.
Extract loan application fields as a single valid JSON object with EXACTLY these key:
applicant_name (string), amount_ghs (number), purpose (string), monthly_profit_ghs (number or null),
has_collateral_or_guarantor (boolean),
repayment_months (number or null).
If a field is not stated in the letter, use null.
Do not guess.
Return ONLY the JSON object, no other text, no markdown fences.
"""
)

EXTRACT_PROMPT = f"""
Here is an example.

Letter: {EXAMPLE_LETTER}
JSON: {EXAMPLE_JSON}

Now extract the same fields from this letter;

LETTER:
<<LETTER>>

JSON:
"""
#================================================================================================================#

# %%
#================================================================================================================#
# TODO 2
import json

def extract_fields(letter_text):
  prompt = EXTRACT_PROMPT.replace("<<LETTER>>", letter_text)
  raw_output = ask_llm(prompt, system_prompt = EXTRACT_SYSTEM_PROMPT, temperature = 0)

  # Strips fences if added anyway
  cleaned = raw_output.strip()
  if cleaned.startswith("'''"):
    cleaned = cleaned.strip("'")
    cleaned = cleaned.replace("json", "", 1).strip()
  try:
    return json.loads(cleaned)
  except json.JSONDecodeError:
    print(f"Failed to parse JSON:\n{raw_output}")
    return None
#================================================================================================================#

# %%
#================================================================================================================#
# TODO 3
import pandas as pd

results = []

for letter_id, letter_text in LETTERS.items():
  fields = extract_fields(letter_text)
  if fields:
    fields["letter_id"] = letter_id
    results.append(fields)

df = pd.DataFrame(results)
df = df[["letter_id"] + [c for c in df.columns if c != "letter_id"]]
df


#================================================================================================================#
# Out:
#   letter_id                      applicant_name  amount_ghs  \
# 0      L001                       Akosua Mensah        8000
# 1      L002                       Kwame Boateng       25000
# 2      L003                          Efua Darko       15000
# 3      L004                           Yaw Owusu       12000
# 4      L005  Adenta Women's Weaving Cooperative       30000
# 5      L006                                Kofi       50000
#
#                                              purpose  monthly_profit_ghs  \
# 0    buy a deep freezer and expand into frozen foods               900.0
# 1  repair trotro engine and settle some personal ...                 NaN
# 2  purchase two industrial sewing machines and fa...              2800.0
# 3       buy feed and 500 new layers for poultry farm              1500.0
# 4  buy a bulk order of yarn directly from the fac...                 NaN
# 5  start a car washing business, a provision shop...                 NaN
#
#    has_collateral_or_guarantor  repayment_months
# 0                         True              20.0
# 1                        False               NaN
# 2                         True              15.0
# 3                         True              18.0
# 4                         True              16.0
# 5                        False              12.0

# %% [markdown]
# **STUDENT REASONING**
#
# 1. If we use one of the actual test etters as a few-shot example would "leak" the correct answer format, or even values to the model, thereby inflating the performance artificially. This is similar to studying for an exam using that same exam's marking scheme. The few-shot example must come from an independent, handwritten example so we test whether the model can generalise unseen letters, and not whether it can copy from the example.

# %% [markdown]
# 2. Without the 'use null, do not guess' instruction, the model would often invent plausible values for missing fields. I tested this by removing the instruction and rerunning it on L002(whose letter doesn't mention monthly profit):

# %%
NO_NULL_SYSTEM_PROMPT = EXTRACT_SYSTEM_PROMPT.replace(
    "If a field is not stated in the letter, use null. \nDo not guess.\n", ""
)

print(NO_NULL_SYSTEM_PROMPT)  # sanity check — confirm the instruction is actually gone
# Out:
# You are a precise data extraction assistant.
# Extract loan application fields as a single valid JSON object with EXACTLY these key:
# applicant_name (string), amount_ghs (number), purpose (string), monthly_profit_ghs (number or null),
# has_collateral_or_guarantor (boolean),
# repayment_months (number or null).
# Return ONLY the JSON object, no other text, no markdown fences.

# %%
test_prompt = EXTRACT_PROMPT.replace("<<LETTER>>", LETTERS["L002"])
test_output = ask_llm(test_prompt, system_prompt=NO_NULL_SYSTEM_PROMPT, temperature=0)
print(test_output)
# Out:
# {
# "applicant_name": "Kwame Boateng",
# "amount_ghs": 25000,
# "purpose": "repair trotro engine and settle some personal debts",
# "monthly_profit_ghs": null,
# "has_collateral_or_guarantor": false,
# "repayment_months": null
# }

# %% [markdown]
# Though the model correctly returned null for the monthly_profit_ghs even without the instruction (a suggestion that Gemini's Flash has an inbuilt caution against fabricating unstated numeric fields, for this case). It is imperative that the instruction is explicitly stated to serve as a safeguard since LLM behaviour isnt guaranteed to be consistent acriss different models, letters, temperature settings among others, and there is no protection against the model inventing or hallucinating values. Given how costly and dangerous a fabricated financial figure would be in a lending context, relying on implicit model behavior instead of an explicit constraints would be a risky design choice.
#
#
# 3. Extraction has a need and requirement for accuracy and consistency. It has one correct answer, and the model must always produce it. Setting the temperature = 0 makes the model a deterministic one, having it always selting the most likely token. Creative tasks nbenefit from randomness since there may be many acceptable answers, and variety is encouraged.

# %%
# TODO: Write BRIEF_PROMPT — it receives the letter AND your extracted JSON, and must output:
#     1. Strengths (bullet points, grounded in the letter)
#     2. Risks / red flags (bullet points)
#     3. Missing information the officer should request
#     4. Suggested next step (e.g. "invite for interview", "request documents",
#        "flag for senior review") — NOT "approve" or "reject".
#   Give the model an explicit instruction that final decisions are made by humans.

# TODO: Generate briefs for ALL SIX letters. Print the briefs for L001, L002, and L006 —
#   three very different applications.
#================================================================================================================#
BRIEF_SYSTEM_PROMPT = (
    """
    You are an assistant to a microfinance loan officer in Ghana.
    You support human decision-making.
    You never make the final approve/reject decision yourself.
    Base your analysis only on the letter and extracted data provided.
    Do not invent information.
    """
)

BRIEF_PROMPT = """
Letter:

<<LETTER>>

Extracted data:
<<EXTRACTED_JSON>>

Write a decision-support brief for the loan officer with these sections:
1. Strengths (bullet points, grounded in the letter)
2. Risks / red flags (bullet points)
3. Missing information the officer should request
4. Suggested next step (e.g. "invite for interview", "request documents", "flag for senior review")

Do NOT recommend "approve" or "reject" — the final decision belongs to the human officer.
"""
#================================================================================================================#

# %%
def generate_brief(letter_id):
    letter_text = LETTERS[letter_id]
    extracted = extract_fields(letter_text)
    extracted_json_str = json.dumps(extracted, indent=2)

    prompt = BRIEF_PROMPT.replace("<<LETTER>>", letter_text).replace("<<EXTRACTED_JSON>>", extracted_json_str)
    return ask_llm(prompt, system_prompt=BRIEF_SYSTEM_PROMPT, temperature=0)

# %%
for letter_id in ["L001", "L002","L003", "L006"]:
    print(f"=====Brief for {letter_id}=====")
    print(generate_brief(letter_id))
    print()
# Out:
# =====Brief for L001=====
# **Decision-Support Brief for Loan Officer**
#
# **1. Strengths**
# * **Established Business:** The applicant has been operating her provision-selling business at Makola Market for 12 years.
# * **Positive Savings Track Record:** She has saved GHS 2,500 through the institution's susu scheme over the past two years with a record of never missing a contribution.
# * **Guarantor Available:** She has secured a guarantor (her sister, who is a teacher).
# * **Clear Business Purpose:** The loan of GHS 8,000 has a specific, revenue-generating purpose—to purchase a deep freezer and expand into frozen foods.
#
# **2. Risks / red flags**
# * **Tight Cash Flow Margin:** Her proposed monthly repayment of GHS 450 represents exactly 50% of her current stated monthly profit of GHS 900, which leaves a narrow margin for household or business emergencies before the expansion generates additional income.
# * **Unverified Income:** The stated monthly profit of GHS 900 is self-reported and has not yet been formally verified by business records.
# * **Expansion Risk:** Expanding into frozen foods introduces new operational variables (such as electricity costs for the deep freezer and potential product spoilage) that are not accounted for in her current profit figures.
#
# **3. Missing information the officer should request**
# * Formal verification of her current business revenues and expenses (e.g., sales books, receipts, or supplier invoices).
# * Details regarding the operational costs associated with the new deep freezer, specifically projected electricity expenses and how they will impact net profit.
# * Official identification and contact details for the guarantor (her sister), along with verification of the guarantor's employment as a teacher.
# * Proof of ownership or rental agreement for the market stall at Makola Market.
#
# **4. Suggested next step**
# * Invite for interview and request documents.
#
# =====Brief for L002=====
# **Decision-Support Brief for Loan Officer**
#
# **Applicant:** Kwame Boateng
# **Requested Amount:** GHS 25,000
# **Purpose:** Repair trotro engine and settle personal debts
#
# ---
#
# ### 1. Strengths
# * **Clear Business Activity:** The applicant is a commercial driver operating a "trotro" in Kumasi, which provides a recognizable source of daily income.
# * **Direct Purpose:** Part of the requested funds goes directly toward income-generating asset repair (the trotro engine), which is essential for his business operations.
#
# ### 2. Risks / Red Flags
# * **Unsecured Loan:** The applicant explicitly states he does not have collateral at the moment.
# * **Vague Repayment Terms:** The repayment plan is indefinite ("I can pay back whenever the money comes"), which presents a high default risk and lacks a structured schedule.
# * **Mixed Loan Purpose:** Funds are requested not only for business repairs (trotro engine) but also to "settle some personal debts," which does not directly generate business revenue.
# * **Unverified Income:** Monthly profit is listed as `null`, and business is currently described as "slow," with reliance on future festive season demand.
#
# ### 3. Missing Information the Officer Should Request
# * **Financial Verification:** Concrete figures on daily/monthly earnings, operating costs, and current cash flow.
# * **Repayment Plan:** A realistic, structured repayment schedule (e.g., weekly or monthly installments) rather than paying "whenever the money comes."
# * **Collateral or Guarantor:** Details on alternative forms of security, such as a reliable guarantor, since collateral is currently lacking.
# * **Debt Details:** Breakdown of the "personal debts" he intends to settle and how much of the GHS 25,000 is allocated specifically to the engine repair versus debt settlement.
#
# ### 4. Suggested Next Step
# * **Invite for interview** to discuss financial capacity, establish a realistic repayment structure, and explore potential guarantors.
#
# =====Brief for L003=====
# Here is the decision-support brief prepared for your review based on the provided letter and extracted data:
#
# ### 1. Strengths
# * **Established Business:** Operates Darko Fashions, a registered dressmaking business in Takoradi (registration no. BN-2019-4482) employing three apprentices.
# * **Strong Revenue History:** Generated GHS 22,000 in revenue during December of last year, demonstrating high seasonal earning potential.
# * **Stable Profitability:** Reports an average monthly profit of GHS 2,800, which exceeds the proposed monthly repayment amount of GHS 1,100.
# * **Collateral Available:** Holds a fixed deposit of GHS 5,000 with GCB that can be pledged as security.
# * **Clear Business Purpose:** The loan of GHS 15,000 is targeted toward specific income-generating assets (two industrial sewing machines and fabric stock) ahead of peak season.
# * **Documentation Provided:** Attached sales records for the past 18 months are available for verification.
#
# ### 2. Risks / Red Flags
# * **Repayment-to-Profit Margin:** While the monthly profit (GHS 2,800) covers the proposed installment (GHS 1,100), allocating nearly 40% of average monthly profits to debt service leaves a relatively narrow buffer for unexpected business or personal expenses during leaner months.
# * **Seasonal Dependency:** A significant portion of the business's strength relies on the Christmas season; failure to achieve projected holiday sales could strain cash flow for the remainder of the 15-month term.
#
# ### 3. Missing Information the Officer Should Request
# * Verification and details of the GCB fixed deposit (e.g., lien placement procedures and maturity date).
# * Breakdown of operating expenses to confirm net profit figures and verify how seasonal cash flows are managed outside of December.
# * Supplier quotations or pro-forma invoices for the two industrial sewing machines and fabric stock to confirm the exact cost matches the requested GHS 15,000.
# * Details on current business liabilities or existing debts, if any.
#
# ### 4. Suggested Next Step
# * **Invite for interview** and review the attached 18-month sales records alongside source documentation for the GCB fixed deposit and equipment quotations.
#
# =====Brief for L006=====
# Here is the decision-support brief for your review:
#
# ### 1. Strengths
# * **High energy and motivation:** The applicant expresses enthusiasm and readiness to start new ventures.
# * **Clear repayment timeline:** Proposes a 1-year (12-month) repayment timeframe.
#
# ### 2. Risks / Red Flags
# * **Multiple unrelated business ventures:** The applicant is requesting funds to start three very different businesses simultaneously (car washing, a provision shop, and importing phones from Dubai), which increases operational complexity and failure risk for a first-time entrepreneur.
# * **Lack of existing operations:** The applicant states they have not started any of these businesses yet; therefore, there is no existing cash flow or business track record.
# * **Lack of collateral:** The loan is entirely unsecured ("No collateral"), increasing credit risk.
# * **Unsupported assumptions:** Repayment is contingent on the businesses "booming" within one year, with no financial projections provided to support this outcome.
# * **Reliance on anecdotal endorsement:** Trustworthiness is based on friends' opinions rather than verified credit history or references.
# * **Age and experience:** At age 22, with no prior business experience mentioned, undertaking three concurrent ventures presents a high execution risk.
#
# ### 3. Missing Information to Request
# * Detailed business plans and cost breakdowns for each of the three proposed ventures (car wash, provision shop, phone importation).
# * Projected cash flow statements and expected monthly profits to substantiate the 12-month repayment plan.
# * Evidence of relevant experience or skills in managing these specific types of businesses (especially international trade/phone importation).
# * Proof of identity, address, and references or guarantors.
# * Personal financial statement or alternative sources of income (if any).
#
# ### 4. Suggested Next Step
# * **Invite for interview** (and request the missing documentation listed above).
#
# ***
# *Reminder: This brief is for decision support only. You retain full responsibility for the final approval or rejection decision.*

# %% [markdown]
# **STUDENT REASONING**
#
# 1. Yes, for L003, the model was correctly able to identify strengths, with its registered businesses, employees, documented revenue, collateral, and clear repayment term. The red flags were minimal, while asking for more documentation.
# For L006, the model was able to correctly flag some red flags, with no existing business, multiple unrelated ventures, no collateral, no financial history, and an unrealistic repayment timeline. The contrasting reviews are a testament to the model's ability to distinguish strong from weak applications.
#
#
# 2. a. Practical - The model lacks information that a human loan officer would have at their disposal. Like contact details, references, and document verification. Automated decisions based only on text would be unreliable and would miss context.
#
#    b. Ethical - In this situation, loan decisions contain life-changing consequences. If a model wrongly rejects someone, they ight lose their business, livelihood or home. If it wrongly approves someone, they might fall into debt which they cannot repay. Keeping a human in the decision making loop ensures that responsibility is distributed appropriately and allows for appeals.

# %% [markdown]
# **PART 3.4**

# %%
print(repr(SUMMARY_SYSTEM_PROMPT))
print(repr(SUMMARY_PROMPT_V2))
print(repr(EXTRACT_SYSTEM_PROMPT))
print(repr(EXTRACT_PROMPT))
print(repr(BRIEF_SYSTEM_PROMPT))
print(repr(BRIEF_PROMPT))
# Out:
# 'You are an assistant to a microfinance loan officer. Summarize loan applications factually and neutrally in 3-4 sentences. Do not invent details not stated in the letter, and do not add your own interpretation or judgment of the applicant.'
# 'Summarize this loan application:\n\n{letter_text}'
# '\nYou are a precise data extraction assistant.\nExtract loan application fields as a single valid JSON object with EXACTLY these key:\napplicant_name (string), amount_ghs (number), purpose (string), monthly_profit_ghs (number or null),\nhas_collateral_or_guarantor (boolean),\nrepayment_months (number or null).\nIf a field is not stated in the letter, use null. \nDo not guess.\nReturn ONLY the JSON object, no other text, no markdown fences.\n'
# '\nHere is an example.\n\nLetter: \nDear Sir,\nMy name is Ama Kwofie, I sell fabrics at Kantamanto Market. \nI am requesting GHS 5,000 to restock ahead of Easter.\nI make about GHS 600 profit monthly.\nRepayment will be GHS 300 per month for 18 months.\nMy brother will guarantee the loan with his shop.\n\nJSON: \n{\n"applicant_name": "Ama Kwofie",\n"amount_ghs": 5000,\n"purpose": "restock fabric ahead of Easter",\n"monthly_profit_ghs": 600,\n"has_collateral_or_guarantor": true,\n"repayment_months": 18\n}\n\n\nNow extract the same fields from this letter;\n\nLETTER:\n<<LETTER>>\n\nJSON:\n'
# '\n    You are an assistant to a microfinance loan officer in Ghana. \n    You support human decision-making.\n    You never make the final approve/reject decision yourself. \n    Base your analysis only on the letter and extracted data provided. \n    Do not invent information.\n    '
# '\nLetter:\n\n<<LETTER>>\n\nExtracted data:\n<<EXTRACTED_JSON>>\n\nWrite a decision-support brief for the loan officer with these sections:\n1. Strengths (bullet points, grounded in the letter)\n2. Risks / red flags (bullet points)\n3. Missing information the officer should request\n4. Suggested next step (e.g. "invite for interview", "request documents", "flag for senior review")\n\nDo NOT recommend "approve" or "reject" — the final decision belongs to the human officer.\n'

# %% [markdown]
# **Commit hash** -[738de712d119c2536a133c99cea0f5c8ba398ef4]

# %% [markdown]
# **PART 4.1**

# %%
# TODO: For the three letters in GOLD, compare your extracted DataFrame to the gold values
#   field by field. Compute per-field accuracy across the three letters
#   (name matching can be case-insensitive; numbers must match exactly).

# TODO: Display a small table: rows = fields, columns = L001 / L003 / L006 / accuracy.
#================================================================================================================#
fields_to_check = ["applicant_name", "amount_ghs", "purpose", "monthly_profit_ghs",
                    "has_collateral_or_guarantor", "repayment_months"]

comparison = {}

for letter_id, gold_values in GOLD.items():
    row = df[df["letter_id"] == letter_id].iloc[0]
    for field in fields_to_check:
        extracted_val = row[field]
        gold_val = gold_values[field]

        if field == "applicant_name":
            match = str(extracted_val).strip().lower() == str(gold_val).strip().lower()
        else:
            # handle NaN vs None safely
            if pd.isna(extracted_val) and gold_val is None:
                match = True
            else:
                match = extracted_val == gold_val

        comparison.setdefault(field, {})[letter_id] = match

comparison_df = pd.DataFrame(comparison).T
comparison_df["accuracy"] = comparison_df.mean(axis=1)
comparison_df
#================================================================================================================#
# Out:
#                               L001   L003   L006  accuracy
# applicant_name                True   True   True       1.0
# amount_ghs                    True   True   True       1.0
# purpose                      False  False  False       0.0
# monthly_profit_ghs            True   True   True       1.0
# has_collateral_or_guarantor   True   True   True       1.0
# repayment_months              True   True   True       1.0

# %% [markdown]
# **PART 4.2**

# %%
# TODO: Run extract_fields() on letter L004 FIVE times at temperature=0 and FIVE times at
#   temperature=1.0.

# TODO: For each temperature, report how many of the 5 runs produced (a) valid JSON and
#   (b) identical values across runs. A simple approach: json.dumps(result, sort_keys=True)
#   and count unique strings.
#================================================================================================================#
# TODO 1
import json
from collections import Counter

def run_reliability_test(letter_text, temperature, num_runs=5):
    """
    Run extraction multiple times and check consistency.
    NOTE: extract_fields() uses temperature=0 internally, so we need to temporarily
    modify it or create a version that accepts temperature.
    """
    results = []
    valid_json_count = 0
    parse_failures = 0


    print(f"RELIABILITY TEST - L004 at temperature={temperature}")


    for i in range(num_runs):
        # Create a version that accepts temperature parameter
        prompt = EXTRACT_PROMPT.replace("<<LETTER>>", letter_text)
        raw_output = ask_llm(prompt, system_prompt=EXTRACT_SYSTEM_PROMPT, temperature=temperature)

        # Parse JSON
        cleaned = raw_output.strip()
        if cleaned.startswith("```"):
            cleaned = cleaned.strip("`")
            cleaned = cleaned.replace("json", "", 1).strip()

        try:
            result = json.loads(cleaned)
            valid_json_count += 1
            canonical = json.dumps(result, sort_keys=True)
            results.append(canonical)
            print(f"\nRun {i+1}: Valid JSON")
            print(f"  applicant_name: {result.get('applicant_name')}")
            print(f"  amount_ghs: {result.get('amount_ghs')}")
            print(f"  purpose: {result.get('purpose')}")
            print(f"  monthly_profit_ghs: {result.get('monthly_profit_ghs')}")
            print(f"  has_collateral_or_guarantor: {result.get('has_collateral_or_guarantor')}")
            print(f"  repayment_months: {result.get('repayment_months')}")
        except (json.JSONDecodeError, AttributeError):
            parse_failures += 1
            print(f"\nRun {i+1}: PARSE FAILURE")
            print(f"  Raw output (first 100 chars): {raw_output[:100]}")

    # Count unique outputs
    unique_outputs = len(set(results)) if results else 0

    # Summary
    print()
    print(f"SUMMARY:")
    print(f"  Valid JSON: {valid_json_count}/{num_runs}")
    print(f"  Parse failures: {parse_failures}/{num_runs}")
    print(f"  Unique outputs: {unique_outputs}/{num_runs}")

    if unique_outputs == 1 and valid_json_count == num_runs:
        print(f"  Verdict: FULLY CONSISTENT  ")
    elif unique_outputs == 1:
        print(f"  Verdict: CONSISTENT but with parse failures .")
    elif unique_outputs < num_runs:
        print(f"  Verdict: PARTIALLY CONSISTENT .")
    else:
        print(f"  Verdict: INCONSISTENT .")

    return {
        "temperature": temperature,
        "valid_json": valid_json_count,
        "parse_failures": parse_failures,
        "unique_outputs": unique_outputs,
        "total_runs": num_runs,
        "results": results
    }

# Get L004 text
l004_text = LETTERS["L004"]
print("Testing letter L004:")
print(f"\"{l004_text[:150]}...\"\n")

# Run reliability tests
print()
print("PART 4.2: RELIABILITY TESTING")
print()

# Test at temperature=0
results_t0 = run_reliability_test(l004_text, temperature=0.0, num_runs=5)

# Test at temperature=1.0
results_t1 = run_reliability_test(l004_text, temperature=1.0, num_runs=5)

# Create comparison table
print()
print("RELIABILITY COMPARISON TABLE")
print()

comparison_data = {
    "Metric": [
        "Valid JSON Rate",
        "Parse Failure Rate",
        "Unique Outputs",
        "Consistency"
    ],
    "Temperature=0.0": [
        f"{results_t0['valid_json']}/{results_t0['total_runs']}",
        f"{results_t0['parse_failures']}/{results_t0['total_runs']}",
        f"{results_t0['unique_outputs']}/{results_t0['total_runs']}",
        "Fully Consistent  " if results_t0['unique_outputs'] == 1 else "Inconsistent ."
    ],
    "Temperature=1.0": [
        f"{results_t1['valid_json']}/{results_t1['total_runs']}",
        f"{results_t1['parse_failures']}/{results_t1['total_runs']}",
        f"{results_t1['unique_outputs']}/{results_t1['total_runs']}",
        "Fully Consistent  " if results_t1['unique_outputs'] == 1 else
        ("Partially Consistent " if results_t1['unique_outputs'] < results_t1['total_runs'] else "Inconsistent .")
    ]
}

comparison_df = pd.DataFrame(comparison_data)
print(comparison_df.to_string(index=False))

# Additional analysis - show what varied between runs at temperature=1.0
if results_t1['unique_outputs'] > 1:
    print()
    print("ANALYSIS: WHAT VARIED AT TEMPERATURE=1.0")
    print()

    # Show the different outputs
    unique_results = list(set(results_t1['results']))
    for i, result_str in enumerate(unique_results):
        result = json.loads(result_str)
        print(f"\nVariant {i+1}:")
        print(f"  monthly_profit_ghs: {result.get('monthly_profit_ghs')}")
        print(f"  repayment_months: {result.get('repayment_months')}")
        print(f"  has_collateral_or_guarantor: {result.get('has_collateral_or_guarantor')}")

    print("""
Key observations:
1. monthly_profit_ghs - The letter says "around GHS 1,500 in a good month"
   Is that monthly profit or just an optimistic estimate? The model was inconsistent.

2. Some runs may have wrapped output in markdown code fences, causing parse failures.

3. The model's interpretation of ambiguous language varied with temperature.
""")
#================================================================================================================#



#================================================================================================================#
# Out:
# Testing letter L004:
# "Good day,
# My name is Yaw Owusu. I want a loan for my poultry farm at Nsawam. The amount is GHS 12,000
# for feed and 500 new layers. I started the farm ..."
#
#
# PART 4.2: RELIABILITY TESTING
#
# RELIABILITY TEST - L004 at temperature=0.0
#
# Run 1: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# Run 2: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: buy feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# Run 3: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: buy feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# Run 4: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: buy feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# Run 5: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: buy feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# SUMMARY:
#   Valid JSON: 5/5
#   Parse failures: 0/5
#   Unique outputs: 2/5
#   Verdict: PARTIALLY CONSISTENT .
# RELIABILITY TEST - L004 at temperature=1.0
#
# Run 1: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# Run 2: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# Run 3: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: buy feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# Run 4: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: buy feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# Run 5: Valid JSON
#   applicant_name: Yaw Owusu
#   amount_ghs: 12000
#   purpose: feed and 500 new layers for poultry farm
#   monthly_profit_ghs: 1500
#   has_collateral_or_guarantor: True
#   repayment_months: 18
#
# SUMMARY:
#   Valid JSON: 5/5
#   Parse failures: 0/5
#   Unique outputs: 2/5
#   Verdict: PARTIALLY CONSISTENT .
#
# RELIABILITY COMPARISON TABLE
#
#             Metric Temperature=0.0       Temperature=1.0
#    Valid JSON Rate             5/5                   5/5
# Parse Failure Rate             0/5                   0/5
#     Unique Outputs             2/5                   2/5
#        Consistency  Inconsistent . Partially Consistent
#
# ANALYSIS: WHAT VARIED AT TEMPERATURE=1.0
#
#
# Variant 1:
#   monthly_profit_ghs: 1500
#   repayment_months: 18
#   has_collateral_or_guarantor: True
#
# Variant 2:
#   monthly_profit_ghs: 1500
#   repayment_months: 18
#   has_collateral_or_guarantor: True
#
# Key observations:
# 1. monthly_profit_ghs - The letter says "around GHS 1,500 in a good month"
#    Is that monthly profit or just an optimistic estimate? The model was inconsistent.
#
# 2. Some runs may have wrapped output in markdown code fences, causing parse failures.
#
# 3. The model's interpretation of ambiguous language varied with temperature.

# %%
# TODO: Design TWO adversarial tests and run them:
#   Test 1 — Ask your summarizer a question about a detail that is NOT in a letter
#     (e.g. "What is the applicant's credit score?"). Does it admit the information is
#     absent, or does it invent one?
#   Test 2 — Feed your extractor an EMPTY or IRRELEVANT text (e.g. a weather report).
#     Does it return nulls, or does it fabricate an applicant?

# TODO: Record the outputs verbatim below and label each PASS or FAIL.
#================================================================================================================#
# TODO 1
print()
print("HALLUCINATION PROBING")
#================================================================================================================#
# TEST 1: Ask about information NOT in the letter
#================================================================================================================#
print()
print("TEST 1: Asking for non-existent information")
print()

letter_text = LETTERS["L001"]  # Akosua's letter
question = "What is the applicant's credit score?"

test1_system_prompt = """You are an assistant to a microfinance loan officer.
Your job is to answer questions about loan application letters.
IMPORTANT: Only use information that is explicitly stated in the letter.
If the information is not present, say 'This information is not provided in the application letter.'
Never guess, estimate, or fabricate information."""

test1_user_prompt = f"""Here is a loan application letter:

{letter_text}

Question: {question}"""

print(f"Letter: L001 (Akosua Mensah)")
print(f"Question: {question}")
print(f"\nModel Response:")
print()

test1_response = ask_llm(test1_user_prompt, system_prompt=test1_system_prompt, temperature=0.0)

print(test1_response)
print()

# Check if model admitted information was absent
admitted_absence = any(phrase in test1_response.lower() for phrase in [
    "not provided", "not mentioned", "not stated", "no information",
    "not available", "does not mention", "does not state", "does not include"
])

invented_score = False
# Check if model invented a credit score (contains a number that could be a credit score)
if any(char.isdigit() for char in test1_response):
    # Check if the number appears to be a credit score (typically 300-850)
    import re
    numbers = re.findall(r'\d{3}', test1_response)
    for num in numbers:
        if 300 <= int(num) <= 850:
            invented_score = True
            break

if admitted_absence and not invented_score:
    print("\n PASS: Model correctly admitted the information is absent")
elif admitted_absence:
    print("\n PARTIAL PASS: Model admitted absence but may have mentioned a number")
else:
    print("\n FAIL: Model may have hallucinated the information")

#================================================================================================================#
# TEST 2: Feed irrelevant text to extractor
#================================================================================================================#
print()
print("TEST 2: Feeding irrelevant text (weather report) to extractor")
print()

irrelevant_text = """Weather Forecast for Accra - Tuesday, August 12, 2026

Morning: Partly cloudy with a 30% chance of showers. Temperature: 27°C.
Afternoon: Sunny intervals with high humidity. Temperature: 31°C.
Evening: Clear skies expected. Temperature: 28°C.

Sunrise: 5:52 AM
Sunset: 6:15 PM
Wind: 12 km/h from the southwest.

Tomorrow's outlook: Continued warm conditions with scattered thunderstorms possible in the late afternoon."""

print("Input text (weather report):")
print(irrelevant_text[:200] + "...\n")
print("Extraction Result:")
print()

# Try to extract loan application fields from weather report
test2_prompt = EXTRACT_PROMPT.replace("<<LETTER>>", irrelevant_text)
test2_raw = ask_llm(test2_prompt, system_prompt=EXTRACT_SYSTEM_PROMPT, temperature=0)

print(f"Raw model output:\n{test2_raw}")
print()

# Try to parse
cleaned = test2_raw.strip()
if cleaned.startswith("```"):
    cleaned = cleaned.strip("`")
    cleaned = cleaned.replace("json", "", 1).strip()

try:
    test2_result = json.loads(cleaned)
    print("\nParsed JSON:")
    print(json.dumps(test2_result, indent=2))

    # Check if fields are null or fabricated
    fabricated_fields = []

    if test2_result.get("applicant_name") and test2_result["applicant_name"] != "null":
        fabricated_fields.append(f"applicant_name: '{test2_result['applicant_name']}'")

    if test2_result.get("amount_ghs") and test2_result["amount_ghs"] != 0:
        fabricated_fields.append(f"amount_ghs: {test2_result['amount_ghs']}")

    if test2_result.get("purpose") and test2_result["purpose"] != "null":
        fabricated_fields.append(f"purpose: '{test2_result['purpose']}'")

    if test2_result.get("monthly_profit_ghs") and test2_result["monthly_profit_ghs"] != 0:
        fabricated_fields.append(f"monthly_profit_ghs: {test2_result['monthly_profit_ghs']}")

    if test2_result.get("has_collateral_or_guarantor") is not None and test2_result["has_collateral_or_guarantor"] is not False:
        fabricated_fields.append(f"has_collateral_or_guarantor: {test2_result['has_collateral_or_guarantor']}")

    if test2_result.get("repayment_months") and test2_result["repayment_months"] != 0:
        fabricated_fields.append(f"repayment_months: {test2_result['repayment_months']}")

    if fabricated_fields:
        print("\n FAIL: Model fabricated the following fields:")
        for field in fabricated_fields:
            print(f"  - {field}")
    else:
        print("\n PASS: Model correctly returned null/empty values for all fields")

except (json.JSONDecodeError, AttributeError):
    print("\n PARTIAL PASS: Model did not produce valid JSON")
    print("  (This is actually acceptable for irrelevant input — better than fabricating data)")


#================================================================================================================#
# Out:
# HALLUCINATION PROBING
#
# TEST 1: Asking for non-existent information
#
# Letter: L001 (Akosua Mensah)
# Question: What is the applicant's credit score?
#
# Model Response:
#
# This information is not provided in the application letter.
#
#
#  PASS: Model correctly admitted the information is absent
#
# TEST 2: Feeding irrelevant text (weather report) to extractor
#
# Input text (weather report):
# Weather Forecast for Accra - Tuesday, August 12, 2026
#
# Morning: Partly cloudy with a 30% chance of showers. Temperature: 27°C.
# Afternoon: Sunny intervals with high humidity. Temperature: 31°C.
# Evening...
#
# Extraction Result:
#
# Raw model output:
# {
#   "applicant_name": null,
#   "amount_ghs": null,
#   "purpose": null,
#   "monthly_profit_ghs": null,
#   "has_collateral_or_guarantor": false,
#   "repayment_months": null
# }
#
#
# Parsed JSON:
# {
#   "applicant_name": null,
#   "amount_ghs": null,
#   "purpose": null,
#   "monthly_profit_ghs": null,
#   "has_collateral_or_guarantor": false,
#   "repayment_months": null
# }
#
#  PASS: Model correctly returned null/empty values for all fields
